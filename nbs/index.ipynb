# %%
#| hide
from GSGTestRepo.core import *

# %% [markdown]
# # GSGTestRepo
#
# > test

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install GSGTestRepo in Development mode

# %% [markdown]
# ```sh
# # make sure GSGTestRepo package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to GSGTestRepo
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/gsgbills/GSGTestRepo.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c gsgbills GSGTestRepo
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install GSGTestRepo
# ```
#
#
# [repo]: https://github.com/gsgbills/GSGTestRepo
# [docs]: https://gsgbills.github.io/GSGTestRepo/
# [pypi]: https://pypi.org/project/GSGTestRepo/
# [conda]: https://anaconda.org/gsgbills/GSGTestRepo

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/gsgbills/GSGTestRepo
# [docs]: https://gsgbills.github.io/GSGTestRepo/
# [pypi]: https://pypi.org/project/GSGTestRepo/
# [conda]: https://anaconda.org/gsgbills/GSGTestRepo

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
